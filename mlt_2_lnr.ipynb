# %% [markdown]
# <a href="https://colab.research.google.com/github/abrameshba/ML_SADUP/blob/main/mlt_2_lnr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Linear Regression**
#
# Three major uses for regression analysis are
# 1. determining the strength of predictors.
# 2. forecasting an effect, and
# 3. trend forecasting.
#
# The regression has five key assumptions:
# 1.   Linear relationship.
# 2.   Multivariate normality.
# 3.   No or little multicollinearity.
# 4.   No auto-correlation/Independence.
# 5.   Homoscedasticity.
#
# ![scedasticity.png](data:image/png;base64,...)

# %%
from google.colab import drive
drive.mount("/content/drive/", force_remount=True)
import pandas as pd
df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/train.csv")
# Out:
# Mounted at /content/drive/

# %% [markdown]
# y = a x + b
#
# y is regressand (dependent variable)
#
# x is regressor (independent variable)
#
# a slope
#
# b intercept
# \begin{align}
# a = \frac{(\sum y)(\sum x^2)-(\sum x)(\sum xy)}{n(\sum x^2)-(\sum x)^2}
# \end{align}
#
# \begin{align}
# b = \frac{n(\sum xy)-(\sum x)(\sum y)}{n(\sum x^2)-(\sum x)^2}
# \end{align}

# %% [markdown]
# <table border="1">
# <tr><td>x</td><td>2</td><td>4</td><td>6</td><td>8</td></tr>
# <tr><td>y</td><td>3</td><td>5</td><td>7</td><td>10</td></tr>
# </table>

# %%
from sklearn import linear_model
x = [[2],[4],[6],[8]]
y = [3,5,7,10]
lr = linear_model.LinearRegression()
print(lr.fit(x,y))
print(lr.score(x,y))
print(lr.coef_)
print(lr.intercept_)
print(lr.predict([[10]]))
# Out:
# LinearRegression()
# 0.9887850467289719
# [1.15]
# 0.5
# [12.]

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([2,4,6,8])
y = np.array([3,5,7,10])
#obtain m (slope) and b(intercept) of linear regression line
m, b = np.polyfit(x, y, 1)

#add linear regression line to scatterplot 
plt.plot(x, m*x+b)
plt.scatter(x,y)
plt.show()

# %%
from scipy.stats import linregress
x = [2,4,6,8]
y= [3,5,7,10]
linregress(x,y) #x and y are arrays or lists.
# Out:
# LinregressResult(slope=1.15, intercept=0.5, rvalue=0.9943767126843689, pvalue=0.0056232873156311074, stderr=0.08660254037844395, intercept_stderr=0.4743416490252574)
